# %%
pip install hvplot
# Out:
# Collecting hvplot
#   Downloading hvplot-0.7.3-py2.py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 3.3 MB/s eta 0:00:01
# Collecting colorcet>=2
#   Downloading colorcet-3.0.0-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 9.3 MB/s eta 0:00:01
# Requirement already satisfied: pandas in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from hvplot) (1.2.4)
# Collecting holoviews>=1.11.0
#   Downloading holoviews-1.14.7-py2.py3-none-any.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 3.5 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.15 in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from hvplot) (1.20.1)
# Requirement already satisfied: bokeh>=1.0.0 in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from hvplot) (2.3.2)
# Requirement already satisfied: Jinja2>=2.9 in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from bokeh>=1.0.0->hvplot) (2.11.3)
# Requirement already satisfied: typing-extensions>=3.7.4 in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from bokeh>=1.0.0->hvplot) (3.7.4.3)
# Requirement already satisfied: pillow>=7.1.0 in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from bokeh>=1.0.0->hvplot) (8.2.0)
# Requirement already satisfied: tornado>=5.1 in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from bokeh>=1.0.0->hvplot) (6.1)
# Requirement already satisfied: packaging>=16.8 in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from bokeh>=1.0.0->hvplot) (20.9)
# Requirement already satisfied: PyYAML>=3.10 in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from bokeh>=1.0.0->hvplot) (5.4.1)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from bokeh>=1.0.0->hvplot) (2.8.1)
# Collecting param>=1.7.0
#   Downloading param-1.12.0-py2.py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 3.3 MB/s eta 0:00:011
# Collecting pyct>=0.4.4
#   Downloading pyct-0.4.8-py2.py3-none-any.whl (15 kB)
# Collecting pyviz-comms>=0.7.4
#   Downloading pyviz_comms-2.1.0-py2.py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 7.7 MB/s  eta 0:00:01
# Collecting panel>=0.8.0
#   Downloading panel-0.12.6-py2.py3-none-any.whl (12.9 MB)
#      |████████████████████████████████| 12.9 MB 8.7 MB/s eta 0:00:011
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from Jinja2>=2.9->bokeh>=1.0.0->hvplot) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from packaging>=16.8->bokeh>=1.0.0->hvplot) (2.4.7)
# Requirement already satisfied: pytz>=2017.3 in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from pandas->hvplot) (2021.1)
# Collecting bokeh>=1.0.0
#   Downloading bokeh-2.4.2-py3-none-any.whl (18.5 MB)
#      |████████████████████████████████| 18.5 MB 4.7 MB/s eta 0:00:01    |████████████▍                   | 7.2 MB 6.1 MB/s eta 0:00:02     |████████████████████████▊       | 14.2 MB 4.7 MB/s eta 0:00:01     |███████████████████████████████▋| 18.2 MB 4.7 MB/s eta 0:00:01
# Requirement already satisfied: markdown in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from panel>=0.8.0->holoviews>=1.11.0->hvplot) (3.3.6)
# Requirement already satisfied: tqdm>=4.48.0 in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from panel>=0.8.0->holoviews>=1.11.0->hvplot) (4.59.0)
# Requirement already satisfied: bleach in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from panel>=0.8.0->holoviews>=1.11.0->hvplot) (3.3.0)
# Requirement already satisfied: requests in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from panel>=0.8.0->holoviews>=1.11.0->hvplot) (2.25.1)
# Collecting typing-extensions>=3.7.4
#   Downloading typing_extensions-4.1.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: six>=1.5 in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.1->bokeh>=1.0.0->hvplot) (1.15.0)
# Requirement already satisfied: webencodings in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from bleach->panel>=0.8.0->holoviews>=1.11.0->hvplot) (0.5.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from markdown->panel>=0.8.0->holoviews>=1.11.0->hvplot) (4.10.1)
# Requirement already satisfied: zipp>=0.5 in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown->panel>=0.8.0->holoviews>=1.11.0->hvplot) (3.4.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (1.26.4)
# Installing collected packages: typing-extensions, param, pyviz-comms, pyct, bokeh, panel, colorcet, holoviews, hvplot
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.7.4.3
#     Uninstalling typing-extensions-3.7.4.3:
#       Successfully uninstalled typing-extensions-3.7.4.3
#   Attempting uninstall: bokeh
#     Found existing installation: bokeh 2.3.2
#     Uninstalling bokeh-2.3.2:
#       Successfully uninstalled bokeh-2.3.2
# Successfully installed bokeh-2.4.2 colorcet-3.0.0 holoviews-1.14.7 hvplot-0.7.3 panel-0.12.6 param-1.12.0 pyct-0.4.8 pyviz-comms-2.1.0 typing-extensions-4.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import hvplot.pandas
from path import Path
import plotly.express as px
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
pip install plotly.express
# Out:
# Collecting plotly.express
#   Downloading plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Requirement already satisfied: scipy>=0.18 in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from plotly.express) (1.6.2)
# Requirement already satisfied: numpy>=1.11 in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from plotly.express) (1.20.1)
# Requirement already satisfied: pandas>=0.20.0 in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from plotly.express) (1.2.4)
# Collecting plotly>=4.1.0
#   Downloading plotly-5.6.0-py2.py3-none-any.whl (27.7 MB)
#      |████████████████████████████████| 27.7 MB 9.8 MB/s eta 0:00:011   |██                              | 1.6 MB 1.7 MB/s eta 0:00:16     |█████████████████████████▋      | 22.1 MB 9.8 MB/s eta 0:00:01
# Requirement already satisfied: statsmodels>=0.9.0 in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from plotly.express) (0.12.2)
# Requirement already satisfied: patsy>=0.5 in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from plotly.express) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.20.0->plotly.express) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.20.0->plotly.express) (2021.1)
# Requirement already satisfied: six in /Users/jennybui/opt/anaconda3/lib/python3.8/site-packages (from patsy>=0.5->plotly.express) (1.15.0)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: tenacity, plotly, plotly.express
# Successfully installed plotly-5.6.0 plotly.express tenacity-8.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
crypto_df = pd.read_csv("Resources/crypto_data.csv", index_col=0)
crypto_df
# Out:
#             CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42           42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 365          365Coin       X11       True   PoW/PoS              NaN
# 404          404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 611        SixEleven   SHA-256       True       PoW              NaN
# 808              808   SHA-256       True   PoW/PoS     0.000000e+00
# ...              ...       ...        ...       ...              ...
# XBC      BitcoinPlus    Scrypt       True       PoS     1.283270e+05
# DVTC      DivotyCoin    Scrypt      False   PoW/PoS     2.149121e+07
# GIOT     Giotto Coin    Scrypt      False   PoW/PoS              NaN
# OPSC  OpenSourceCoin   SHA-256      False   PoW/PoS              NaN
# PUNK       SteamPunk       PoS      False       PoS              NaN
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# ...              ...
# XBC          1000000
# DVTC       100000000
# GIOT       233100000
# OPSC        21000000
# PUNK        40000000
#
# [1252 rows x 6 columns]

# %%
# Counting number of rows
crypto_df.count()
# Out:
# CoinName           1252
# Algorithm          1252
# IsTrading          1252
# ProofType          1252
# TotalCoinsMined     744
# TotalCoinSupply    1252
# dtype: int64

# %%
# Checking the different value types
crypto_df.dtypes
# Out:
# CoinName            object
# Algorithm           object
# IsTrading             bool
# ProofType           object
# TotalCoinsMined    float64
# TotalCoinSupply     object
# dtype: object

# %%
# Checking all column names
crypto_df.columns
# Out:
# Index(['CoinName', 'Algorithm', 'IsTrading', 'ProofType', 'TotalCoinsMined',
#        'TotalCoinSupply'],
#       dtype='object')

# %%
# Keep all the cryptocurrencies that are being traded.
crypto_df = crypto_df.loc[crypto_df["IsTrading"]== True]
crypto_df.head(10)
# Out:
#        CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42      42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 365     365Coin       X11       True   PoW/PoS              NaN
# 404     404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 611   SixEleven   SHA-256       True       PoW              NaN
# 808         808   SHA-256       True   PoW/PoS     0.000000e+00
# 1337  EliteCoin       X13       True   PoW/PoS     2.927942e+10
# 2015  2015 coin       X11       True   PoW/PoS              NaN
# BTC     Bitcoin   SHA-256       True       PoW     1.792718e+07
# ETH    Ethereum    Ethash       True       PoW     1.076842e+08
# LTC    Litecoin    Scrypt       True       PoW     6.303924e+07
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# 1337    314159265359
# 2015               0
# BTC         21000000
# ETH                0
# LTC         84000000

# %%
# Keep all the cryptocurrencies that have a working algorithm.
crypto_df = crypto_df.loc[crypto_df["Algorithm"].isna() != True]
crypto_df.head(10)
# Out:
#        CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42      42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 365     365Coin       X11       True   PoW/PoS              NaN
# 404     404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 611   SixEleven   SHA-256       True       PoW              NaN
# 808         808   SHA-256       True   PoW/PoS     0.000000e+00
# 1337  EliteCoin       X13       True   PoW/PoS     2.927942e+10
# 2015  2015 coin       X11       True   PoW/PoS              NaN
# BTC     Bitcoin   SHA-256       True       PoW     1.792718e+07
# ETH    Ethereum    Ethash       True       PoW     1.076842e+08
# LTC    Litecoin    Scrypt       True       PoW     6.303924e+07
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# 1337    314159265359
# 2015               0
# BTC         21000000
# ETH                0
# LTC         84000000

# %%
# Remove the "IsTrading" column. 
crypto_df = crypto_df.drop("IsTrading", axis=1)
crypto_df.head(10)
# Out:
#        CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42      42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 365     365Coin       X11   PoW/PoS              NaN      2300000000
# 404     404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 611   SixEleven   SHA-256       PoW              NaN          611000
# 808         808   SHA-256   PoW/PoS     0.000000e+00               0
# 1337  EliteCoin       X13   PoW/PoS     2.927942e+10    314159265359
# 2015  2015 coin       X11   PoW/PoS              NaN               0
# BTC     Bitcoin   SHA-256       PoW     1.792718e+07        21000000
# ETH    Ethereum    Ethash       PoW     1.076842e+08               0
# LTC    Litecoin    Scrypt       PoW     6.303924e+07        84000000

# %%
# Remove rows that have at least 1 null value.
crypto_df = crypto_df.dropna()
crypto_df.head(10)
# Out:
#               CoinName       Algorithm ProofType  TotalCoinsMined  \
# 42             42 Coin          Scrypt   PoW/PoS     4.199995e+01
# 404            404Coin          Scrypt   PoW/PoS     1.055185e+09
# 808                808         SHA-256   PoW/PoS     0.000000e+00
# 1337         EliteCoin             X13   PoW/PoS     2.927942e+10
# BTC            Bitcoin         SHA-256       PoW     1.792718e+07
# ETH           Ethereum          Ethash       PoW     1.076842e+08
# LTC           Litecoin          Scrypt       PoW     6.303924e+07
# DASH              Dash             X11   PoW/PoS     9.031294e+06
# XMR             Monero  CryptoNight-V7       PoW     1.720114e+07
# ETC   Ethereum Classic          Ethash       PoW     1.133597e+08
#
#      TotalCoinSupply
# 42                42
# 404        532000000
# 808                0
# 1337    314159265359
# BTC         21000000
# ETH                0
# LTC         84000000
# DASH        22000000
# XMR                0
# ETC        210000000

# %%
# Keep the rows where coins are mined.
crypto_df = crypto_df.drop(
    crypto_df.loc[crypto_df["TotalCoinsMined"] <= 0].index,
)
crypto_df.head(10)
# Out:
#               CoinName       Algorithm ProofType  TotalCoinsMined  \
# 42             42 Coin          Scrypt   PoW/PoS     4.199995e+01
# 404            404Coin          Scrypt   PoW/PoS     1.055185e+09
# 1337         EliteCoin             X13   PoW/PoS     2.927942e+10
# BTC            Bitcoin         SHA-256       PoW     1.792718e+07
# ETH           Ethereum          Ethash       PoW     1.076842e+08
# LTC           Litecoin          Scrypt       PoW     6.303924e+07
# DASH              Dash             X11   PoW/PoS     9.031294e+06
# XMR             Monero  CryptoNight-V7       PoW     1.720114e+07
# ETC   Ethereum Classic          Ethash       PoW     1.133597e+08
# ZEC              ZCash        Equihash       PoW     7.383056e+06
#
#      TotalCoinSupply
# 42                42
# 404        532000000
# 1337    314159265359
# BTC         21000000
# ETH                0
# LTC         84000000
# DASH        22000000
# XMR                0
# ETC        210000000
# ZEC         21000000

# %%
# Create a new DataFrame that holds only the cryptocurrencies names.
crypto_names = crypto_df[["CoinName"]] 
crypto_names.head()
# Out:
#        CoinName
# 42      42 Coin
# 404     404Coin
# 1337  EliteCoin
# BTC     Bitcoin
# ETH    Ethereum

# %%
# Use get_dummies() to create variables for text features.
X = pd.get_dummies(crypto_df, columns=["Algorithm","ProofType"])
X.head(10)
# Out:
#       TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# 42       4.199995e+01              42                                 0
# 404      1.055185e+09       532000000                                 0
# 1337     2.927942e+10    314159265359                                 0
# BTC      1.792718e+07        21000000                                 0
# ETH      1.076842e+08               0                                 0
# LTC      6.303924e+07        84000000                                 0
# DASH     9.031294e+06        22000000                                 0
# XMR      1.720114e+07               0                                 0
# ETC      1.133597e+08       210000000                                 0
# ZEC      7.383056e+06        21000000                                 0
#
#       Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# 42                0                  0                   0                0
# 404               0                  0                   0                0
# 1337              0                  0                   0                0
# BTC               0                  0                   0                0
# ETH               0                  0                   0                0
# LTC               0                  0                   0                0
# DASH              0                  0                   0                0
# XMR               0                  0                   0                0
# ETC               0                  0                   0                0
# ZEC               0                  0                   0                0
#
#       Algorithm_Blake2S  Algorithm_Blake2b  Algorithm_C11  ...  \
# 42                    0                  0              0  ...
# 404                   0                  0              0  ...
# 1337                  0                  0              0  ...
# BTC                   0                  0              0  ...
# ETH                   0                  0              0  ...
# LTC                   0                  0              0  ...
# DASH                  0                  0              0  ...
# XMR                   0                  0              0  ...
# ETC                   0                  0              0  ...
# ZEC                   0                  0              0  ...
#
#       ProofType_PoW/PoS  ProofType_PoW/PoS   ProofType_PoW/PoW  \
# 42                    1                   0                  0
# 404                   1                   0                  0
# 1337                  1                   0                  0
# BTC                   0                   0                  0
# ETH                   0                   0                  0
# LTC                   0                   0                  0
# DASH                  1                   0                  0
# XMR                   0                   0                  0
# ETC                   0                   0                  0
# ZEC                   0                   0                  0
#
#       ProofType_PoW/nPoS  ProofType_Pos  ProofType_Proof of Authority  \
# 42                     0              0                             0
# 404                    0              0                             0
# 1337                   0              0                             0
# BTC                    0              0                             0
# ETH                    0              0                             0
# LTC                    0              0                             0
# DASH                   0              0                             0
# XMR                    0              0                             0
# ETC                    0              0                             0
# ZEC                    0              0                             0
#
#       ProofType_Proof of Trust  ProofType_TPoS  \
# 42                           0               0
# 404                          0               0
# 1337                         0               0
# BTC                          0               0
# ETH                          0               0
# LTC                          0               0
# DASH                         0               0
# XMR                          0               0
# ETC                          0               0
# ZEC                          0               0
#
#       ProofType_Zero-Knowledge Proof  ProofType_dPoW/PoW
# 42                                 0                   0
# 404                                0                   0
# 1337                               0                   0
# BTC                                0                   0
# ETH                                0                   0
# LTC                                0                   0
# DASH                               0                   0
# XMR                                0                   0
# ETC                                0                   0
# ZEC                                0                   0
#
# [10 rows x 98 columns]

# %%
# Standardize the data with StandardScaler().
crypto_df = StandardScaler().fit_transform(X)

# %%
# Using PCA to reduce dimension to three principal components.
pca = PCA(n_components=3)
crypto_pca = pca.fit_transform(crypto_df)
pcas_df = pd.DataFrame(
    data=crypto_pca, columns=["PC 1", "PC 2", "PC 3"]
)
pcas_df.head()
# Out:
#        PC 1      PC 2      PC 3
# 0 -0.336135  1.029374 -0.520198
# 1 -0.319474  1.029614 -0.520692
# 2  2.306467  1.705112 -0.691077
# 3 -0.146106 -1.293032  0.164122
# 4 -0.151530 -2.056916  0.306622

# %%
pca.explained_variance_ratio_
# Out:
# array([0.02793132, 0.02140591, 0.02048999])

# %%
# Find the best value for K
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of K values
for i in k:
	km = KMeans(n_clusters=i, random_state=0)
	km.fit(pcas_df)
	inertia.append(km.inertia_)

# Create the elbow curve
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow.hvplot.line(x="k", y="inertia", xticks=k, title="Elbow Curve")
# Out:
# :Curve   [k]   (inertia)

# %%
# Initialize the K-means model
model = KMeans(n_clusters=3, random_state=0)

# Fit the model
model.fit(pcas_df)

# Predict clusters
predictions = model.predict(pcas_df)

# Add the predicted class columns
pcas_df["class"] = model.labels_
pcas_df.head()
# Out:
#        PC 1      PC 2      PC 3  class
# 0 -0.336135  1.029374 -0.520198      1
# 1 -0.319474  1.029614 -0.520692      1
# 2  2.306467  1.705112 -0.691077      1
# 3 -0.146106 -1.293032  0.164122      0
# 4 -0.151530 -2.056916  0.306622      0

# %%
# 3. Create a new DataFrame named “clustered_df,” that includes 
#the following columns: Algorithm, ProofType, TotalCoinsMined, TotalCoinSupply, 
#PC 1, PC 2, PC 3, CoinName, and Class. 
# this did not work ---
clustered_df = pd.concat([crypto_df, pcas_df], axis=1)

#  Add a new column, "CoinName" to the clustered_df DataFrame that holds the names of the cryptocurrencies. 
clustered_df['CoinName'] = coin_name_df["CoinName"]

#  Add a new column, "Class" to the clustered_df DataFrame that holds the predictions.
clustered_df["Class"] = model.labels_

# Print the shape of the clustered_df
print(clustered_df.shape)
clustered_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-0dc5907b7fda> in <module>
#       4 #clustered_df = [pcs_df2, coins_name, crypto_df2]
#       5 # this did not work ---
# ----> 6 clustered_df = pd.concat([crypto_df, pcas_df], axis=1)
#       7
#       8 #  Add a new column, "CoinName" to the clustered_df DataFrame that holds the names of the cryptocurrencies.
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     283     ValueError: Indexes have overlapping values: ['a']
#     284     """
# --> 285     op = _Concatenator(
#     286         objs,
#     287         axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     368                     "only Series and DataFrame objs are valid"
#     369                 )
# --> 370                 raise TypeError(msg)
#     371
#     372             # consolidate
#
# TypeError: cannot concatenate object of type '<class 'numpy.ndarray'>'; only Series and DataFrame objs are valid

# %%
# Check plotly express table
px.scatter_3d
# Out:
# <function plotly.express._chart_types.scatter_3d(data_frame=None, x=None, y=None, z=None, color=None, symbol=None, size=None, text=None, hover_name=None, hover_data=None, custom_data=None, error_x=None, error_x_minus=None, error_y=None, error_y_minus=None, error_z=None, error_z_minus=None, animation_frame=None, animation_group=None, category_orders=None, labels=None, size_max=None, color_discrete_sequence=None, color_discrete_map=None, color_continuous_scale=None, range_color=None, color_continuous_midpoint=None, symbol_sequence=None, symbol_map=None, opacity=None, log_x=False, log_y=False, log_z=False, range_x=None, range_y=None, range_z=None, title=None, template=None, width=None, height=None)>

# %%
# Creating a 3D-Scatter with the PCA data and the clusters
fig = px.scatter_3d(
    clustered_df,
    x="PC 1", 
    y="PC 2",
    z="PC 3",
    color="Class",
    hover_name="CoinName",
    hover_data=["Algorithm"],
    symbol="Class",
    width=800
)
fig.update_layout(legend=dict(x=0, y=1))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-cc00728bc5ec> in <module>
#       1 # Creating a 3D-Scatter with the PCA data and the clusters
#       2 fig = px.scatter_3d(
# ----> 3     clustered_df,
#       4     x="PC 1",
#       5     y="PC 2",
#
# NameError: name 'clustered_df' is not defined

# %%
# Create a table with tradable cryptocurrencies.
clustered_df.hvplot.table(columns=["CoinName", "Algorithm", "ProofType", "TotalCoinSupply", "TotalCoinsMined", "Class"], sortable=True, selectable=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-b3d0447d39e1> in <module>
#       1 # Create a table with tradable cryptocurrencies.
# ----> 2 clustered_df.hvplot.table(columns=["CoinName", "Algorithm", "ProofType", "TotalCoinSupply", "TotalCoinsMined", "Class"], sortable=True, selectable=True)
#
# NameError: name 'clustered_df' is not defined

# %%
# Scaling data to create the scatter plot with tradable cryptocurrencies.
scaling_data = clustered_df.copy()
scaling_data_2 = scaling_data.drop(
    ["Algorithm", "ProofType","PC 1", "PC 2", "PC 3", "CoinName", "Class"], 
    axis=1
)
min_max = MinMaxScaler().fit_transform(scaling_data_2)
min_max

# %%
# Create a new DataFrame that has the scaled data with the clustered_df DataFrame index.
# Create DF for new data
min_max_df = pd.DataFrame(
    data=min_max,
    columns=["TotalCoinsMined", "TotalCoinSupply"],
    index=clustered_df.index
)

# Reorder columns
plot_df = min_max_df.reindex(columns=["TotalCoinSupply","TotalCoinsMined"])

# Add the "CoinName" column from the clustered_df DataFrame to the new DataFrame.
plot_df["CoinName"] = coin_name_df["CoinName"]

# Add the "Class" column from the clustered_df DataFrame to the new DataFrame. 
plot_df["Class"] = clustered_df["Class"]

plot_df.head(10)

# %%
# Create a hvplot.scatter plot using x="TotalCoinsMined" and y="TotalCoinSupply".
plot_df.hvplot.scatter(
    x="TotalCoinsMined",
    y="TotalCoinSupply",
    by="Class",
    hover_cols=["CoinName"],
)
